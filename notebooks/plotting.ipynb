# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

sys.path.append(os.path.abspath(".."))

from IPython.display import display


from src.aux.aux import *
from src.plots.plots import *
from src.utils.config import *
from src.utils.paths import *

# %% [markdown]
# # Parameters

# %%
config = load_config()

color = ['teal', 'darkorange', 'red', 'green', 'yellow']
qaoa_type = config["qaoa_parameters"]["type"]

loaded_data = read_pickle_files_from_directory(GRAPH_DIR)
sorted_loaded_data = dict(
    sorted(
        loaded_data.items(),
        key=lambda item: int(item[0].split('_')[0])
    )
)

amount = 1
s_sorted_loaded_data = dict(list(sorted_loaded_data.items())[:amount])
graphs_str = get_graphs_name(s_sorted_loaded_data)
qaoa_type_index = 2
name_str = qaoa_type[qaoa_type_index]

# %%
result_data = read_result_data(graphs_str, name_str, AER_SIM_DIR)

# %%
fig = objective_circuit_plot(graphs_str, result_data, color, name_str, AER_SIM_PLOT_DIR)
fig.show()
# Out:
# /tmp/ipykernel_21218/2710508497.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
